# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
# Out:
# WARNING:tensorflow:From c:\Users\anush\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load the data
df = pd.read_csv('Weather Data.csv', index_col='Date/Time', parse_dates=['Date/Time']).dropna()

# Select the features
features = ['Temp_C', 'Dew Point Temp_C', 'Rel Hum_%']
data = df[features].values

# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(data)

# %%
# Define sequence length
sequence_length = 30

# %%
# Prepare data for training
X, y = [], []
for i in range(len(data_scaled) - sequence_length):
    X.append(data_scaled[i:i+sequence_length])
    y.append(data_scaled[i+sequence_length])

X, y = np.array(X), np.array(y)

# %%
# Split the dataset into training and testing sets
split = int(0.8 * len(data_scaled))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(units=32, input_shape=(X.shape[1], X.shape[2]), activation="relu"))
model.add(Dense(8, activation="relu"))
model.add(Dense(3)) 
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From c:\Users\anush\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\anush\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=30, validation_split=0.1, verbose=1)

# Make predictions on the test set
test_predictions_scaled = model.predict(X_test)

# Inverse transform the entire test set for plotting
X_test_inverse = scaler.inverse_transform(X_test[:, -1, :])
y_test_inverse = scaler.inverse_transform(y_test)
test_predictions = scaler.inverse_transform(test_predictions_scaled)
# Out:
# Epoch 1/50
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 2/50
# 211/211 [==============================] - 2s 12ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 3/50
# 211/211 [==============================] - 2s 12ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 4/50
# 211/211 [==============================] - 3s 12ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 5/50
# 211/211 [==============================] - 2s 12ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 6/50
# 211/211 [==============================] - 2s 12ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 7/50
# 211/211 [==============================] - 2s 11ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 8/50
# 211/211 [==============================] - 2s 12ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 9/50
# 211/211 [==============================] - 3s 12ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 10/50
# 211/211 [==============================] - 2s 12ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 11/50
# 211/211 [==============================] - 2s 12ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 12/50
# 211/211 [==============================] - 2s 12ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 13/50
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 14/50
# 211/211 [==============================] - 2s 12ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 15/50
# 211/211 [==============================] - 3s 12ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 16/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 17/50
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 18/50
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 19/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 20/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 21/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 22/50
# 211/211 [==============================] - 2s 12ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 23/50
# 211/211 [==============================] - 3s 12ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 24/50
# 211/211 [==============================] - 3s 12ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 25/50
# 211/211 [==============================] - 3s 12ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 26/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 27/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 28/50
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 29/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 30/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 31/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 32/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 33/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 34/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 35/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 36/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 37/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 38/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 39/50
# 211/211 [==============================] - 3s 16ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 40/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 41/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 42/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 43/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 44/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 45/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 46/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 47/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 48/50
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 49/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 50/50
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0012 - val_loss: 0.0013
# 54/54 [==============================] - 0s 7ms/step

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))

# Plot the results
for i in range(2):
    plt.plot(df.index[split+sequence_length:], y_test_inverse[:, i], label='Actual ' + features[i])
    plt.plot(df.index[split+sequence_length:], test_predictions[:, i], label='Predicted ' + features[i], linestyle='dashed')

plt.ylabel('Values')
plt.xlabel('Date')
plt.legend()
plt.title('LSTM Multivariate')
plt.tight_layout()
plt.show()

# %%
# Plot actual vs predicted for each feature as subplots
plt.figure(figsize=(12, 8))

# Plot the results
for i in range(3):
    plt.subplot(3, 1, i+1)
    plt.plot(df.index[split+sequence_length:], y_test_inverse[:, i], label='Actual ' + features[i])
    plt.plot(df.index[split+sequence_length:], test_predictions[:, i], label='Predicted ' + features[i], linestyle='dashed')
    plt.ylabel(features[i])
    plt.legend()

plt.xlabel('Date')
plt.tight_layout()
plt.show()

# %%
# Calculate RMSE for each feature
rmse_per_feature = []
for i in range(3):
    rmse_feature = np.sqrt(mean_squared_error(y_test_inverse[:, i], test_predictions[:, i]))
    rmse_per_feature.append(rmse_feature)
    print("RMSE for", features[i], ":", rmse_feature)
# Out:
# RMSE for Temp_C : 0.8029062292830681
# RMSE for Dew Point Temp_C : 0.8128448857985018
# RMSE for Rel Hum_% : 4.04016226791549

# %%
# Plot epochs vs loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
